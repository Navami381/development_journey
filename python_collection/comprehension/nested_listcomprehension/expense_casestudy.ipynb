# %%
expenses = [
    {"owner": "Farsin", "amount": 180, "date": "01-08-2026", "category": "Food", "payment_method": "UPI"},
    {"owner": "Farsin", "amount": 450, "date": "01-08-2026", "category": "Transport", "payment_method": "Card"},
    {"owner": "Anjali", "amount": 1200, "date": "01-08-2026", "category": "Shopping", "payment_method": "Card"},
    {"owner": "Rahul", "amount": 850, "date": "01-08-2026", "category": "Fuel", "payment_method": "Cash"},
    {"owner": "Nithin", "amount": 250, "date": "01-08-2026", "category": "Food", "payment_method": "Cash"},
    {"owner": "Meera", "amount": 3000, "date": "01-08-2026", "category": "Rent", "payment_method": "Bank Transfer"},
    {"owner": "Arya", "amount": 150, "date": "02-08-2026", "category": "Snacks", "payment_method": "UPI"},
    {"owner": "Farsin", "amount": 200, "date": "02-08-2026", "category": "Food", "payment_method": "UPI"},
    {"owner": "Rahul", "amount": 500, "date": "02-08-2026", "category": "Entertainment", "payment_method": "Card"},
    {"owner": "Nithin", "amount": 1200, "date": "02-08-2026", "category": "Shopping", "payment_method": "UPI"},
    {"owner": "Anjali", "amount": 350, "date": "02-08-2026", "category": "Transport", "payment_method": "Cash"},
    {"owner": "Meera", "amount": 600, "date": "02-08-2026", "category": "Medical", "payment_method": "Card"},
    {"owner": "Arya", "amount": 90, "date": "02-08-2026", "category": "Tea", "payment_method": "Cash"},
    {"owner": "Farsin", "amount": 1500, "date": "03-08-2026", "category": "Electronics", "payment_method": "Card"},
    {"owner": "Rahul", "amount": 220, "date": "03-08-2026", "category": "Food", "payment_method": "UPI"},
    {"owner": "Nithin", "amount": 450, "date": "03-08-2026", "category": "Fuel", "payment_method": "Cash"},
    {"owner": "Anjali", "amount": 300, "date": "03-08-2026", "category": "Snacks", "payment_method": "UPI"},
    {"owner": "Meera", "amount": 1800, "date": "03-08-2026", "category": "Shopping", "payment_method": "Card"},
    {"owner": "Arya", "amount": 120, "date": "03-08-2026", "category": "Food", "payment_method": "Cash"},
    {"owner": "Farsin", "amount": 250, "date": "03-08-2026", "category": "Transport", "payment_method": "UPI"},
    {"owner": "Rahul", "amount": 999, "date": "04-08-2026", "category": "Internet", "payment_method": "Card"},
    {"owner": "Nithin", "amount": 4500, "date": "04-08-2026", "category": "Rent", "payment_method": "Bank Transfer"},
    {"owner": "Anjali", "amount": 280, "date": "04-08-2026", "category": "Food", "payment_method": "UPI"},
    {"owner": "Meera", "amount": 120, "date": "04-08-2026", "category": "Tea", "payment_method": "Cash"},
    {"owner": "Arya", "amount": 850, "date": "04-08-2026", "category": "Fuel", "payment_method": "Card"},
    {"owner": "Farsin", "amount": 420, "date": "04-08-2026", "category": "Medical", "payment_method": "UPI"},
    {"owner": "Rahul", "amount": 700, "date": "04-08-2026", "category": "Entertainment", "payment_method": "Card"},
    {"owner": "Nithin", "amount": 180, "date": "04-08-2026", "category": "Food", "payment_method": "Cash"},
    {"owner": "Anjali", "amount": 2500, "date": "05-08-2026", "category": "Shopping", "payment_method": "Card"},
    {"owner": "Meera", "amount": 300, "date": "05-08-2026", "category": "Transport", "payment_method": "UPI"},
    {"owner": "Arya", "amount": 150, "date": "05-08-2026", "category": "Snacks", "payment_method": "Cash"},
    {"owner": "Farsin", "amount": 180, "date": "05-08-2026", "category": "Food", "payment_method": "UPI"},
    {"owner": "Farsin", "amount": 500, "date": "05-08-2026", "category": "Food", "payment_method": "UPI"},
    {"owner": "Rahul", "amount": 1250, "date": "05-08-2026", "category": "Fuel", "payment_method": "Card"},
    {"owner": "Nithin", "amount": 650, "date": "05-08-2026", "category": "Medical", "payment_method": "UPI"},
    {"owner": "Anjali", "amount": 400, "date": "05-08-2026", "category": "Entertainment", "payment_method": "Cash"},
    {"owner": "Meera", "amount": 100, "date": "05-08-2026", "category": "Tea", "payment_method": "UPI"},
    {"owner": "Arya", "amount": 3200, "date": "06-08-2026", "category": "Rent", "payment_method": "Bank Transfer"},
    {"owner": "Farsin", "amount": 210, "date": "06-08-2026", "category": "Food", "payment_method": "Cash"},
    {"owner": "Rahul", "amount": 450, "date": "06-08-2026", "category": "Transport", "payment_method": "UPI"},
    {"owner": "Nithin", "amount": 850, "date": "06-08-2026", "category": "Fuel", "payment_method": "Card"},
    {"owner": "Anjali", "amount": 1800, "date": "06-08-2026", "category": "Electronics", "payment_method": "Card"},
    {"owner": "Meera", "amount": 250, "date": "06-08-2026", "category": "Food", "payment_method": "UPI"},
    {"owner": "Arya", "amount": 300, "date": "06-08-2026", "category": "Medical", "payment_method": "Cash"},
    {"owner": "Farsin", "amount": 1200, "date": "07-08-2026", "category": "Shopping", "payment_method": "Card"},
    {"owner": "Rahul", "amount": 220, "date": "07-08-2026", "category": "Snacks", "payment_method": "UPI"},
    {"owner": "Nithin", "amount": 350, "date": "07-08-2026", "category": "Food", "payment_method": "Cash"},
    {"owner": "Anjali", "amount": 180, "date": "07-08-2026", "category": "Transport", "payment_method": "UPI"},
    {"owner": "Meera", "amount": 900, "date": "07-08-2026", "category": "Entertainment", "payment_method": "Card"},
    {"owner": "Arya", "amount": 450, "date": "07-08-2026", "category": "Fuel", "payment_method": "Cash"},
    {"owner": "Farsin", "amount": 140, "date": "08-08-2026", "category": "Tea", "payment_method": "UPI"},
    {"owner": "Rahul", "amount": 2750, "date": "08-08-2026", "category": "Shopping", "payment_method": "Card"},
    {"owner": "Nithin", "amount": 230, "date": "08-08-2026", "category": "Food", "payment_method": "Cash"},
    {"owner": "Anjali", "amount": 650, "date": "08-08-2026", "category": "Medical", "payment_method": "UPI"},
    {"owner": "Meera", "amount": 300, "date": "08-08-2026", "category": "Transport", "payment_method": "Cash"},
    {"owner": "Arya", "amount": 1000, "date": "08-08-2026", "category": "Internet", "payment_method": "Card"},
    {"owner": "Farsin", "amount": 550, "date": "09-08-2026", "category": "Fuel", "payment_method": "UPI"},
    {"owner": "Rahul", "amount": 240, "date": "09-08-2026", "category": "Food", "payment_method": "Cash"},
    {"owner": "Nithin", "amount": 4200, "date": "09-08-2026", "category": "Rent", "payment_method": "Bank Transfer"},
    {"owner": "Anjali", "amount": 500, "date": "09-08-2026", "category": "Entertainment", "payment_method": "Card"},
    {"owner": "Meera", "amount": 175, "date": "09-08-2026", "category": "Tea", "payment_method": "Cash"},
    {"owner": "Arya", "amount": 1350, "date": "09-08-2026", "category": "Shopping", "payment_method": "UPI"},
    {"owner": "Farsin", "amount": 280, "date": "10-08-2026", "category": "Food", "payment_method": "UPI"},
    {"owner": "Rahul", "amount": 900, "date": "10-08-2026", "category": "Fuel", "payment_method": "Card"},
    {"owner": "Nithin", "amount": 240, "date": "10-08-2026", "category": "Transport", "payment_method": "Cash"},
    {"owner": "Anjali", "amount": 1600, "date": "10-08-2026", "category": "Electronics", "payment_method": "Card"},
    {"owner": "Meera", "amount": 320, "date": "10-08-2026", "category": "Food", "payment_method": "UPI"},
    {"owner": "Arya", "amount": 150, "date": "10-08-2026", "category": "Snacks", "payment_method": "Cash"},
    {"owner": "Farsin", "amount": 450, "date": "10-08-2026", "category": "Medical", "payment_method": "Card"},
    {"owner": "Rahul", "amount": 200, "date": "10-08-2026", "category": "Tea", "payment_method": "UPI"},
]

# %%
#display all owners
all_owners={e.get("owner") for e in expenses}
all_owners
# Out:
# {'Anjali', 'Arya', 'Farsin', 'Meera', 'Nithin', 'Rahul'}

# %%
#all transactions
all_transac={e.get("payment_method") for e in expenses}
all_transac
# Out:
# {'Bank Transfer', 'Card', 'Cash', 'UPI'}

# %%
#display transactions where owner name startswith 'a'
name_filter=[e for e in expenses if e.get("owner").startswith("A")]
name_filter
# Out:
# [{'owner': 'Anjali',
#   'amount': 1200,
#   'date': '01-08-2026',
#   'category': 'Shopping',
#   'payment_method': 'Card'},
#  {'owner': 'Arya',
#   'amount': 150,
#   'date': '02-08-2026',
#   'category': 'Snacks',
#   'payment_method': 'UPI'},
#  {'owner': 'Anjali',
#   'amount': 350,
#   'date': '02-08-2026',
#   'category': 'Transport',
#   'payment_method': 'Cash'},
#  {'owner': 'Arya',
#   'amount': 90,
#   'date': '02-08-2026',
#   'category': 'Tea',
#   'payment_method': 'Cash'},
#  {'owner': 'Anjali',
#   'amount': 300,
#   'date': '03-08-2026',
#   'category': 'Snacks',
#   'payment_method': 'UPI'},
#  {'owner': 'Arya',
#   'amount': 120,
#   'date': '03-08-2026',
#   'category': 'Food',
#   'payment_method': 'Cash'},
#  {'owner': 'Anjali',
#   'amount': 280,
#   'date': '04-08-2026',
#   'category': 'Food',
#   'payment_method': 'UPI'},
#  {'owner': 'Arya',
#   'amount': 850,
#   'date': '04-08-2026',
#   'category': 'Fuel',
#   'payment_method': 'Card'},
# ...

# %%
#display all ownerwise count
all_owners=[e.get("owner") for e in expenses]
transaction_count={o:all_owners.count(o) for o in all_owners}
transaction_count
# Out:
# {'Farsin': 14,
#  'Anjali': 11,
#  'Rahul': 12,
#  'Nithin': 11,
#  'Meera': 11,
#  'Arya': 11}

# %%
import matplotlib.pyplot as plt
x=transaction_count.keys()
y=transaction_count.values()
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
#total transaction amount for each owner
owner_summary={}
for e in expenses:
    owner=e.get("owner")
    amount=e.get("amount")
    if owner in owner_summary:
        owner_summary[owner]+=amount
    else:
        owner_summary[owner]=amount

owner_summary
# Out:
# {'Farsin': 6510,
#  'Anjali': 9760,
#  'Rahul': 9279,
#  'Nithin': 13100,
#  'Meera': 7865,
#  'Arya': 7810}

# %%
x=owner_summary.keys()
y=owner_summary.values()
plt.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
#transaction with highest amount
max_transac_amt=max([e.get("amount")for e in expenses])
max_transaction=[e for e in expenses if e.get("amount")==max_transac_amt]
max_transaction
# Out:
# [{'owner': 'Nithin',
#   'amount': 4500,
#   'date': '04-08-2026',
#   'category': 'Rent',
#   'payment_method': 'Bank Transfer'}]

# %%
#transaction with lowest amount
min_transac_amt=min([e.get("amount")for e in expenses])
min_transaction=[e for e in expenses if e.get("amount")==min_transac_amt]
min_transaction
# Out:
# [{'owner': 'Arya',
#   'amount': 90,
#   'date': '02-08-2026',
#   'category': 'Tea',
#   'payment_method': 'Cash'}]

# %%
#average transaction
avg_transaction_amt=sum([e.get("amount") for e in expenses])/len(expenses)
avg_transaction_amt
# Out:
# 776.0571428571428

# %%
all_categories=[e.get("category") for e in expenses]
category_summary={c:all_categories.count(c) for c in all_categories}
category_summary
# Out:
# {'Food': 16,
#  'Transport': 8,
#  'Shopping': 7,
#  'Fuel': 8,
#  'Rent': 4,
#  'Snacks': 5,
#  'Entertainment': 5,
#  'Medical': 6,
#  'Tea': 6,
#  'Electronics': 3,
#  'Internet': 2}

# %%
plt.figure(figsize=(12,8))
x=category_summary.keys()
y=category_summary.values()
plt.bar(x,y)
# Out:
# <BarContainer object of 11 artists>

# %%
#total transaction for each category
category_summary={}
for e in expenses:
    category=e.get("category")
    amount=e.get("amount")
    if category in category_summary:
        category_summary[category]+=amount
    else:
        category_summary[category]=amount

category_summary
# Out:
# {'Food': 3990,
#  'Transport': 2520,
#  'Shopping': 12000,
#  'Fuel': 6150,
#  'Rent': 14900,
#  'Snacks': 970,
#  'Entertainment': 3000,
#  'Medical': 3070,
#  'Tea': 825,
#  'Electronics': 4900,
#  'Internet': 1999}

# %%
plt.figure(figsize=(12,8))
x=category_summary.keys()
y=category_summary.values()
plt.bar(x,y)
# Out:
# <BarContainer object of 11 artists>

# %%
payment_method={e.get("payment_method") for e in expenses}
payment_method
# Out:
# {'Bank Transfer', 'Card', 'Cash', 'UPI'}

# %%
payment_summary={}
for e in expenses:
    payment_method=e.get("payment_method")
    amount=e.get("amount")
    if payment_method in payment_summary:
        payment_summary[payment_method] += amount
    else:
        payment_summary[payment_method] = amount
payment_summary
# Out:
# {'UPI': 9520, 'Card': 24299, 'Cash': 5605, 'Bank Transfer': 14900}

# %%
plt.figure(figsize=(6,3))
x=payment_summary.keys()
y=payment_summary.values()
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
highest=max([payment_summary[p] for p in payment_summary])
highest_payment_method=[p for p in payment_summary if payment_summary[p]==highest]
highest_payment_method
# Out:
# ['Card']

# %%
lowest=min([ payment_summary[p] for p in payment_summary])
lowest_payment_method=[p for p in payment_summary if payment_summary[p]==lowest]
lowest_payment_method
# Out:
# ['Cash']
